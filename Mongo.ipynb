# %%
import urllib.parse
import os
import pandas as pd
import json
import datetime

import discord
from discord.ext import commands
from discord import app_commands

from dotenv import load_dotenv
from pymongo import MongoClient

# %%
load_dotenv()
username = os.getenv('MONGO_USERNAME')
password = os.getenv('MONGO_PASSWORD')
username = urllib.parse.quote_plus(username)
password = urllib.parse.quote_plus(password)

# %%
uri = f"mongodb+srv://{username}:{password}@vajrabot.eqvlech.mongodb.net/?retryWrites=true&w=majority&appName=vajrabot"

# Create a new client and connect to the server
client = MongoClient(uri)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

# Access the database
db = client['genshinDB']
collection = db['characters']
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# DF has some weird symbols in 4 places so make sure to change whenever u use, else just always use data
df = pd.read_excel('characters.xlsx', converters={"player":int})
df.to_json('characters.json', orient='records')
with open('characters.json') as f:
    data = json.load(f)

for character in data:
    character["updated"] = pd.Timestamp(character["updated"], unit='ms', tz="UTC").to_pydatetime()

data
# Out:
# [{'name': 'Amber',
#   'tier': 'Tier 3',
#   'region': 'Mondstadt',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Kaeya',
#   'tier': 'Tier 3',
#   'region': 'Mondstadt',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Lisa',
#   'tier': 'Tier 3',
#   'region': 'Mondstadt',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Noelle',
#   'tier': 'Tier 3',
#   'region': 'Mondstadt',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Fischl',
#   'tier': 'Tier 3',
#   'region': 'Mondstadt',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Albedo',
#   'tier': 'Tier 2',
#   'region': 'Mondstadt',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Diluc',
#   'tier': 'Tier 2',
#   'region': 'Mondstadt',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Rosaria',
#   'tier': 'Tier 3',
#   'region': 'Mondstadt',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Mika',
#   'tier': 'Tier 3',
#   'region': 'Mondstadt',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Dahlia',
#   'tier': 'Tier 3',
#   'region': 'Mondstadt',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Eula',
#   'tier': 'Tier 3',
#   'region': 'Mondstadt',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Diona',
#   'tier': 'Tier 3',
#   'region': 'Mondstadt',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Jean',
#   'tier': 'Tier 2',
#   'region': 'Mondstadt',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Barbara',
#   'tier': 'Tier 3',
#   'region': 'Mondstadt',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Bennett',
#   'tier': 'Tier 3',
#   'region': 'Mondstadt',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Sucrose',
#   'tier': 'Tier 3',
#   'region': 'Mondstadt',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Venti',
#   'tier': 'Tier 1',
#   'region': 'Mondstadt',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Mona',
#   'tier': 'Tier 2',
#   'region': 'Mondstadt',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Klee',
#   'tier': 'Tier 3',
#   'region': 'Mondstadt',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Razor',
#   'tier': 'Tier 3',
#   'region': 'Mondstadt',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Xiao',
#   'tier': 'Tier 2',
#   'region': 'Liyue',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Beidou',
#   'tier': 'Tier 3',
#   'region': 'Liyue',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Ningguang',
#   'tier': 'Tier 2',
#   'region': 'Liyue',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Chongyun',
#   'tier': 'Tier 3',
#   'region': 'Liyue',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Baizhu',
#   'tier': 'Tier 3',
#   'region': 'Liyue',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'YaoYao',
#   'tier': 'Tier 3',
#   'region': 'Liyue',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Yelan',
#   'tier': 'Tier 3',
#   'region': 'Liyue',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Xingqiu',
#   'tier': 'Tier 3',
#   'region': 'Liyue',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Xiangling',
#   'tier': 'Tier 3',
#   'region': 'Liyue',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Qiqi',
#   'tier': 'Tier 3',
#   'region': 'Liyue',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Hu Tao',
#   'tier': 'Tier 3',
#   'region': 'Liyue',
#   'status': 'Claimed',
#   'player': 140026874804830208,
#   'type': 'Canon',
#   'sheet': 'https://docs.google.com/document/d/100lzmlySsDAf0dSHegjNt0hiu4s5RE7_f4va-KSGKwY/edit?usp=sharing',
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Keqing',
#   'tier': 'Tier 3',
#   'region': 'Liyue',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Yanfei',
#   'tier': 'Tier 3',
#   'region': 'Liyue',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Gaming',
#   'tier': 'Tier 3',
#   'region': 'Liyue',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Mountain Shaper',
#   'tier': 'Tier 2',
#   'region': 'Liyue',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Shenhe',
#   'tier': 'Tier 2',
#   'region': 'Liyue',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Yun Jin',
#   'tier': 'Tier 3',
#   'region': 'Liyue',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Zhongli',
#   'tier': 'Tier 1',
#   'region': 'Liyue',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Ganyu',
#   'tier': 'Tier 2',
#   'region': 'Liyue',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Xianyun',
#   'tier': 'Tier 2',
#   'region': 'Liyue',
#   'status': 'Reserved',
#   'player': 701201673489612820,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Madame Ping',
#   'tier': 'Tier 3',
#   'region': 'Liyue',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Moon Carver',
#   'tier': 'Tier 2',
#   'region': 'Liyue',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Kamisato Ayaka',
#   'tier': 'Tier 3',
#   'region': 'Inazuma',
#   'status': 'Claimed',
#   'player': 140026874804830208,
#   'type': 'Canon',
#   'sheet': 'https://docs.google.com/document/d/1TELIb89h_B4ZPPqwFnUTywn4ta0jc45F-QlimLmAUmw/edit?usp=sharing',
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Kaedehara Kazuha',
#   'tier': 'Tier 2',
#   'region': 'Inazuma',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Yoimiya',
#   'tier': 'Tier 3',
#   'region': 'Inazuma',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Sayu',
#   'tier': 'Tier 3',
#   'region': 'Inazuma',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Raiden Ei & Shogun',
#   'tier': 'Tier 1',
#   'region': 'Inazuma',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Sara',
#   'tier': 'Tier 3',
#   'region': 'Inazuma',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Kokomi',
#   'tier': 'Tier 2',
#   'region': 'Inazuma',
#   'status': 'Claimed',
#   'player': 140026874804830208,
#   'type': 'Canon',
#   'sheet': 'https://docs.google.com/document/d/1foVOpWGwcPpCrAZS1xUD2_nFEQHn5Xs74rCgWnkCaUU/edit?usp=sharing',
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Thoma',
#   'tier': 'Tier 3',
#   'region': 'Inazuma',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Kamisato Ayato',
#   'tier': 'Tier 2',
#   'region': 'Inazuma',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Kirara',
#   'tier': 'Tier 3',
#   'region': 'Inazuma',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Shinobu',
#   'tier': 'Tier 3',
#   'region': 'Inazuma',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Heizou',
#   'tier': 'Tier 3',
#   'region': 'Inazuma',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Yae Miko',
#   'tier': 'Tier 2',
#   'region': 'Inazuma',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Itto',
#   'tier': 'Tier 3',
#   'region': 'Inazuma',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Gorou',
#   'tier': 'Tier 3',
#   'region': 'Inazuma',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Chiori',
#   'tier': 'Tier 3',
#   'region': 'Inazuma',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Tighnari',
#   'tier': 'Tier 2',
#   'region': 'Sumeru',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Cyno',
#   'tier': 'Tier 2',
#   'region': 'Sumeru',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Nahida',
#   'tier': 'Tier 1',
#   'region': 'Sumeru',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Collei',
#   'tier': 'Tier 3',
#   'region': 'Sumeru',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Dori',
#   'tier': 'Tier 3',
#   'region': 'Sumeru',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Nilou',
#   'tier': 'Tier 3',
#   'region': 'Sumeru',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Layla',
#   'tier': 'Tier 3',
#   'region': 'Sumeru',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Kaveh',
#   'tier': 'Tier 3',
#   'region': 'Sumeru',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Alhaitham',
#   'tier': 'Tier 2',
#   'region': 'Sumeru',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Dehya',
#   'tier': 'Tier 2',
#   'region': 'Sumeru',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Candace',
#   'tier': 'Tier 2',
#   'region': 'Sumeru',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Wanderer',
#   'tier': 'Tier 1',
#   'region': 'Sumeru',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Faruzan',
#   'tier': 'Tier 3',
#   'region': 'Sumeru',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Apep',
#   'tier': 'Tier 1',
#   'region': 'Sumeru',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Furina',
#   'tier': 'Tier 1',
#   'region': 'Fontaine',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Navia',
#   'tier': 'Tier 2',
#   'region': 'Fontaine',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Lyney',
#   'tier': 'Tier 2',
#   'region': 'Fontaine',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Freminet',
#   'tier': 'Tier 2',
#   'region': 'Fontaine',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Charlotte',
#   'tier': 'Tier 3',
#   'region': 'Fontaine',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Chiori',
#   'tier': 'Tier 3',
#   'region': 'Fontaine',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Neuvillette',
#   'tier': 'Tier 1',
#   'region': 'Fontaine',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Clorinde',
#   'tier': 'Tier 2',
#   'region': 'Fontaine',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Lynette',
#   'tier': 'Tier 2',
#   'region': 'Fontaine',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Wriothesley',
#   'tier': 'Tier 2',
#   'region': 'Fontaine',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Sigwinne',
#   'tier': 'Tier 3',
#   'region': 'Fontaine',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Chevreuse',
#   'tier': 'Tier 3',
#   'region': 'Fontaine',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Tsaritsa',
#   'tier': 'Tier 1',
#   'region': 'Snezhnaya',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Capitano',
#   'tier': 'Tier 1',
#   'region': 'Snezhnaya',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Columbina',
#   'tier': 'Tier 1',
#   'region': 'Snezhnaya',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Pulcinella',
#   'tier': 'Tier 1',
#   'region': 'Snezhnaya',
#   'status': 'Claimed',
#   'player': 701201673489612820,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Pantalone',
#   'tier': 'Tier 1',
#   'region': 'Snezhnaya',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Pierro',
#   'tier': 'Tier 1',
#   'region': 'Snezhnaya',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Dottore',
#   'tier': 'Tier 1',
#   'region': 'Snezhnaya',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Arlecchino',
#   'tier': 'Tier 1',
#   'region': 'Snezhnaya',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Sandrone',
#   'tier': 'Tier 1',
#   'region': 'Snezhnaya',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Childe',
#   'tier': 'Tier 1',
#   'region': 'Snezhnaya',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Aether (Abyss)',
#   'tier': 'Tier 1',
#   'region': 'Others',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Lumine (Traveler)',
#   'tier': 'Tier 1',
#   'region': 'Others',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Katheryne',
#   'tier': 'Tier 2',
#   'region': 'Others',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Murata',
#   'tier': 'Tier 1',
#   'region': 'Others',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Rhinedottir',
#   'tier': 'Tier 1',
#   'region': 'Others',
#   'status': 'Trialed',
#   'player': 140026874804830208,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Asmoday',
#   'tier': 'Tier 1',
#   'region': 'Others',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Enjou',
#   'tier': 'Tier 2',
#   'region': 'Others',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Paimon',
#   'tier': 'Tier 1',
#   'region': 'Others',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Dainsleif',
#   'tier': 'Tier 1',
#   'region': 'Others',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Aloy',
#   'tier': 'Tier 3',
#   'region': 'Others',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Dvalin',
#   'tier': 'Tier 1',
#   'region': 'Others',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Alice',
#   'tier': 'Tier 1',
#   'region': 'Others',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Istaroth',
#   'tier': 'Tier 1',
#   'region': 'Others',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Jeht',
#   'tier': 'Tier 3',
#   'region': 'Others',
#   'status': 'Open',
#   'player': None,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None},
#  {'name': 'Barbeloth',
#   'tier': 'Tier 1',
#   'region': 'Others',
#   'status': 'Trialed',
#   'player': 701201673489612820,
#   'type': 'Canon',
#   'sheet': None,
#   'updated': datetime.datetime(2024, 3, 23, 9, 20, 14, 460000, tzinfo=datetime.timezone.utc),
#   'thumb': None}]

# %%
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('65fea8396e48df070ae4ad7f'), ObjectId('65fea8396e48df070ae4ad80'), ObjectId('65fea8396e48df070ae4ad81'), ObjectId('65fea8396e48df070ae4ad82'), ObjectId('65fea8396e48df070ae4ad83'), ObjectId('65fea8396e48df070ae4ad84'), ObjectId('65fea8396e48df070ae4ad85'), ObjectId('65fea8396e48df070ae4ad86'), ObjectId('65fea8396e48df070ae4ad87'), ObjectId('65fea8396e48df070ae4ad88'), ObjectId('65fea8396e48df070ae4ad89'), ObjectId('65fea8396e48df070ae4ad8a'), ObjectId('65fea8396e48df070ae4ad8b'), ObjectId('65fea8396e48df070ae4ad8c'), ObjectId('65fea8396e48df070ae4ad8d'), ObjectId('65fea8396e48df070ae4ad8e'), ObjectId('65fea8396e48df070ae4ad8f'), ObjectId('65fea8396e48df070ae4ad90'), ObjectId('65fea8396e48df070ae4ad91'), ObjectId('65fea8396e48df070ae4ad92'), ObjectId('65fea8396e48df070ae4ad93'), ObjectId('65fea8396e48df070ae4ad94'), ObjectId('65fea8396e48df070ae4ad95'), ObjectId('65fea8396e48df070ae4ad96'), ObjectId('65fea8396e48df070ae4ad97'), ObjectId('65fea8396e48df070ae4ad98'), ObjectId('65fea8396e48df070ae4ad99'), ObjectId('65fea8396e48df070ae4ad9a'), ObjectId('65fea8396e48df070ae4ad9b'), ObjectId('65fea8396e48df070ae4ad9c'), ObjectId('65fea8396e48df070ae4ad9d'), ObjectId('65fea8396e48df070ae4ad9e'), ObjectId('65fea8396e48df070ae4ad9f'), ObjectId('65fea8396e48df070ae4ada0'), ObjectId('65fea8396e48df070ae4ada1'), ObjectId('65fea8396e48df070ae4ada2'), ObjectId('65fea8396e48df070ae4ada3'), ObjectId('65fea8396e48df070ae4ada4'), ObjectId('65fea8396e48df070ae4ada5'), ObjectId('65fea8396e48df070ae4ada6'), ObjectId('65fea8396e48df070ae4ada7'), ObjectId('65fea8396e48df070ae4ada8'), ObjectId('65fea8396e48df070ae4ada9'), ObjectId('65fea8396e48df070ae4adaa'), ObjectId('65fea8396e48df070ae4adab'), ObjectId('65fea8396e48df070ae4adac'), ObjectId('65fea8396e48df070ae4adad'), ObjectId('65fea8396e48df070ae4adae'), ObjectId('65fea8396e48df070ae4adaf'), ObjectId('65fea8396e48df070ae4adb0'), ObjectId('65fea8396e48df070ae4adb1'), ObjectId('65fea8396e48df070ae4adb2'), ObjectId('65fea8396e48df070ae4adb3'), ObjectId('65fea8396e48df070ae4adb4'), ObjectId('65fea8396e48df070ae4adb5'), ObjectId('65fea8396e48df070ae4adb6'), ObjectId('65fea8396e48df070ae4adb7'), ObjectId('65fea8396e48df070ae4adb8'), ObjectId('65fea8396e48df070ae4adb9'), ObjectId('65fea8396e48df070ae4adba'), ObjectId('65fea8396e48df070ae4adbb'), ObjectId('65fea8396e48df070ae4adbc'), ObjectId('65fea8396e48df070ae4adbd'), ObjectId('65fea8396e48df070ae4adbe'), ObjectId('65fea8396e48df070ae4adbf'), ObjectId('65fea8396e48df070ae4adc0'), ObjectId('65fea8396e48df070ae4adc1'), ObjectId('65fea8396e48df070ae4adc2'), ObjectId('65fea8396e48df070ae4adc3'), ObjectId('65fea8396e48df070ae4adc4'), ObjectId('65fea8396e48df070ae4adc5'), ObjectId('65fea8396e48df070ae4adc6'), ObjectId('65fea8396e48df070ae4adc7'), ObjectId('65fea8396e48df070ae4adc8'), ObjectId('65fea8396e48df070ae4adc9'), ObjectId('65fea8396e48df070ae4adca'), ObjectId('65fea8396e48df070ae4adcb'), ObjectId('65fea8396e48df070ae4adcc'), ObjectId('65fea8396e48df070ae4adcd'), ObjectId('65fea8396e48df070ae4adce'), ObjectId('65fea8396e48df070ae4adcf'), ObjectId('65fea8396e48df070ae4add0'), ObjectId('65fea8396e48df070ae4add1'), ObjectId('65fea8396e48df070ae4add2'), ObjectId('65fea8396e48df070ae4add3'), ObjectId('65fea8396e48df070ae4add4'), ObjectId('65fea8396e48df070ae4add5'), ObjectId('65fea8396e48df070ae4add6'), ObjectId('65fea8396e48df070ae4add7'), ObjectId('65fea8396e48df070ae4add8'), ObjectId('65fea8396e48df070ae4add9'), ObjectId('65fea8396e48df070ae4adda'), ObjectId('65fea8396e48df070ae4addb'), ObjectId('65fea8396e48df070ae4addc'), ObjectId('65fea8396e48df070ae4addd'), ObjectId('65fea8396e48df070ae4adde'), ObjectId('65fea8396e48df070ae4addf'), ObjectId('65fea8396e48df070ae4ade0'), ObjectId('65fea8396e48df070ae4ade1'), ObjectId('65fea8396e48df070ae4ade2'), ObjectId('65fea8396e48df070ae4ade3'), ObjectId('65fea8396e48df070ae4ade4'), ObjectId('65fea8396e48df070ae4ade5'), ObjectId('65fea8396e48df070ae4ade6'), ObjectId('65fea8396e48df070ae4 ...

# %%
result = collection.aggregate([
    {
        "$search": {
            "index": "characterSearch",
            "text": {
                "query": "tao",
                "path": {
                "wildcard": "*"
                }
            }
        }
    }
])

result = list(result)
result = result[0]
status = result["status"] if result["status"] == "Open" else f'{result["status"]} by {result["player"]}.'

ts = result["updated"]
discord.utils.format_dt(ts)
# Out:
# '<t:1711156814>'
